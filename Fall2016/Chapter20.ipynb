# %%
import numpy as np
import scipy as sp
import seaborn as sns

# %%
from scipy.stats import poisson

# %%
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
n = 30
nsim = 1000

# %%
mu = np.log(10)
print('mu = {0:.2f}'.format(mu))
print('p_0 = e^(-mu) = {0:.2f}'.format( np.exp(-mu)))
# Out:
# mu = 2.30
# p_0 = e^(-mu) = 0.10

# %%
sample = sp.stats.poisson.rvs(mu=mu, size=n)
print(sample)
# Out:
# [3 0 2 2 1 2 5 2 2 1 7 2 1 2 0 0 1 2 0 3 3 3 3 5 4 3 1 2 2 3]

# %%
(sample == 0).sum()
# Out:
# 4

# %%
sim = sp.stats.poisson.rvs(mu=mu, size=(nsim,n))
print(sim)
# Out:
# [[2 2 0 ..., 5 3 1]
#  [3 2 2 ..., 1 2 1]
#  [6 1 1 ..., 4 3 1]
#  ...,
#  [1 3 1 ..., 2 4 1]
#  [1 2 3 ..., 3 1 4]
#  [1 1 3 ..., 3 1 1]]

# %%
S = ( (sim == 0).sum(axis=1) ).astype(float) / n
#print(S)

# %%
plt.hist(S, color='gray')
plt.xlabel('S')
plt.ylabel('Frequency')
plt.axis([0, 0.35, 0, 250])
# Out:
# [0, 0.35, 0, 250]

# %%
T = np.exp(-1.0* sim.mean(axis=1) )
#print(T)

# %%
plt.hist(T, color='gray')
plt.xlabel('T')
plt.ylabel('Frequency')
plt.axis([0, 0.35, 0, 250])
# Out:
# [0, 0.35, 0, 250]

# %%
X_bar = sim.mean(axis=1)

# %%
plt.hist(X_bar, color='gray')
plt.xlabel('X_bar')
plt.ylabel('Frequency')
plt.axis([0, 5, 0, 300])
# Out:
# [0, 5, 0, 300]

# %%
S_n_squared = (((sim.T - X_bar).T)**2).sum(axis=1) / (n - 1)

# %%
plt.hist(S_n_squared, color='gray')
plt.xlabel('S_n_squared')
plt.ylabel('Frequency')
plt.axis([0, 5, 0, 500])
# Out:
# [0, 5, 0, 500]
